# %% [markdown]
# ## **GTO Poker Regret Minimization Demo Notebook**

# %%
import sys
import os
sys.path.append(os.path.abspath(r'C:\Users\tobys\Downloads\gto-poker-sim'))

from engine.cfr_solver import CFRSolver
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

solver = CFRSolver(num_iterations=10000)
solver.train()
avg_strategy = solver.get_average_strategy()

hands = solver.hands
actions = solver.actions
df = pd.DataFrame(avg_strategy, columns=actions, index=hands)
sns.heatmap(df, annot=True, cmap='YlGnBu', cbar=False)
plt.title('Average Strategy per Hand (Toy GTO Solver)')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 22
#      19 plt.show()
#      21 for val in df.values:
# ---> 22     if val > 0.00005:
#      23         val = 0
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()
